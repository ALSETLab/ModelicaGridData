# %% [markdown]
# Download and Visualize NYISO Actual Load and Forecast Data
# ============================================
# This Jupyter Notebook shows an example on how to use the functionalities of this repository to download, organize and visualize NYISO data
#
# The first cell downloads and organizes the data and plots the actual load, forecast and forecast error for the previous day.

# %%
import os
os.chdir("..")

# %%
from utils import *

# Downloading raw load forecast and actual load data from NYISO website
download_nyiso_data(2018, "data", verbose = True)
# Out:
# /Users/sergio.dorado/Documents/GitHub_Repositories/01_Maintained/Papers/Trajectory_Generation_Tool/utils/pf2rec/em_psse/psse.py:12: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   modes = yaml.load(in_file)
# Updating files of 1/2021
# Files of 1/2021 updated
# Load forecast '.zip' file download completed up to 1/30/2021
# Forecast load '.zip' file organization completed up to 1/30/2021
# Actual load '.zip' file download completed up to 1/30/2021
# Actual load '.zip' file organization completed up to 1/30/2021

# %% [markdown]
# In the cell below, we plot the most recent load information. This cell may require a previous execution of the `download_nyiso_data` function to update the NYISO files to the most recent load/forecast version in the data server.

# %%
import datetime
 
now = datetime.datetime.now() + datetime.timedelta(days = -1)

# Visualizing the actual load, load forecast
date = f"{now.month:02d}/{now.day:02d}/{now.year}"
# Uncomment to plot the day the COVID-19 lockdown started
#date = "03/23/2020"
# Uncomment to plot a holiday (Christmas day)
#date = "12/25/2019"

# NYC
time_stamp, load, forecast, worst_forecast = visualize_load_forecast(date, "N.Y.C.", 
                                                                     data_path = "data",
                                                                     show_plot = True)
# NYISO
time_stamp, load, forecast, worst_forecast = visualize_load_forecast(date, "NYISO",
                                                     data_path = "data",
                                                     show_plot = True)
# Out:
# findfont: Font family ['liberation sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['liberation sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['liberation sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['liberation sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['liberation sans'] not found. Falling back to DejaVu Sans.

# %%
# NYISO
time_stamp, load, forecast, worst_forecast = visualize_load_forecast(date, "NYISO",
                                                     data_path = "data",
                                                     show_plot = True)

# %% [markdown]
# In the cell below, we plot the information for the current month in three different areas of NY grid. The plots are saved under `./data/Figs`.

# %%
_, _, _, _ = get_weekly_behavior(date, "NYISO", "data", True)
# Out:
# findfont: Font family ['liberation sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['liberation sans'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# The cell below runs a function called `compare_weekly_behavior` which compares the behavior of a week throughout several years for a specific zone of the NY grid. It accepts any day of a given week as input.

# %%
_ = compare_weekly_behavior("03/24/2020", [2018, 2020, 2019], "N.Y.C.", "data")

# %% [markdown]
# The last two cells perform similar operations on a monthly basis.

# %%
_ = get_monthly_behavior("03/2020", "NYISO", "data", True)

# %%
_ = compare_monthly_behavior("03/2020", [2019], "NYISO", "data")

# %% [markdown]
# This last cell runs a script to download raw weather forecast data. No further preprocessing is done.

# %%
download_weather_data(2020, "data", True)
# Out:
# Weather Forecast '.zip' file download completed up to 1/30/2021
